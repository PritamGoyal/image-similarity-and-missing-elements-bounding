# %% [markdown]
# <a href="https://colab.research.google.com/github/PritamGoyal/image-similarity-and-missing-elements-bounding/blob/main/assignment2ofdl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow


def detect_and_draw_diff(img1, img2):

    gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)


    diff = cv2.absdiff(gray1, gray2)


    _, thresh = cv2.threshold(diff, 30, 255, cv2.THRESH_BINARY)


    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)


    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(img1, (x, y), (x+w, y+h), (0, 255, 0), 2)


    similarity_score = calculate_similarity(gray1, gray2)
    print("Similarity Score:", similarity_score)


    cv2_imshow(img1)


image1 = cv2.imread("/content/input1.png")
image2 = cv2.imread("/content/input2.png")


detect_and_draw_diff(image1, image2)
# Out:
# Similarity Score: 0.9851897279773418
# <PIL.Image.Image image mode=RGB size=428x926>

# %%
from google.colab.patches import cv2_imshow


def detect_and_draw_diff(img1, img2):

    gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)


    diff = cv2.absdiff(gray1, gray2)


    _, thresh = cv2.threshold(diff, 30, 255, cv2.THRESH_BINARY)


    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)


    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(img2, (x, y), (x+w, y+h), (0, 255, 0), 2)


    similarity_score = calculate_similarity(gray1, gray2)
    print("Similarity Score:", similarity_score)


    cv2_imshow(img2)


image1 = cv2.imread("/content/input1.png")
image2 = cv2.imread("/content/input2.png")


detect_and_draw_diff(image1, image2)
# Out:
# Similarity Score: 0.9851897279773418
# <PIL.Image.Image image mode=RGB size=428x926>
